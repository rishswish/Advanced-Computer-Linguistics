# %% [markdown]
# * NAME: Rishabh Patil
# * SAP: 60009200056
# * BATCH: D12

# %% [markdown]
# #**Lab 4: Implement Information Retrieval for extracting Text from Webpages and Image.**

# %% [markdown]
# #**1. On Sentences**

# %%
# !git clone https://github.com/thunlp/OpenNRE.git
# !cp -r OpenNRE/opennre opennre
# !pip install transformers
# Out:
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
import re
import os
import nltk
import math
import opennre
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import utils
from sklearn import metrics
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from keras.models import Sequential
from nltk.chunk.regexp import RegexpParser
from keras.preprocessing.text import Tokenizer
from keras.layers import Embedding, SimpleRNN, Dense
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from nltk import sent_tokenize, word_tokenize, pos_tag, ne_chunk, RegexpTokenizer, PorterStemmer, WordNetLemmatizer

# %%
nltk.download('all')

# %%
text = "Dr. APJ Abdul Kalam was born in a humble and poor household in Tamil Nadu. He started off by selling newspapers as a boy. His hardwork and perseverance propelled him to become one of India's greatest rocket scientists, instrumental in the foundation of ISRO and DRDO. He went on to become the President of India."

# %% [markdown]
# **Sentence Tokenization**

# %%
sentences = sent_tokenize(text)

# %% [markdown]
# **Word Tokenization, POS Tagging and Named Entity Recognition**

# %%
for sentence in sentences:
    # Word Tokeniation
    words = word_tokenize(sentence)

    # POS Tagging
    pos_tags = pos_tag(words)

    # Named Entity Recognition (NER)
    named_entities = ne_chunk(pos_tags)

    # Extracting and printing named entities along with their types
    for entity in named_entities:
        if isinstance(entity, nltk.Tree):
            entity_name = " ".join([word for word, tag in entity.leaves()])
            entity_type = entity.label()
            print(f"Entity: {entity_name}, Type: {entity_type}")
# Out:
# Entity: Abdul Kalam, Type: PERSON
# Entity: Tamil Nadu, Type: GPE
# Entity: India, Type: GPE
# Entity: ISRO, Type: ORGANIZATION
# Entity: DRDO, Type: ORGANIZATION
# Entity: India, Type: GPE

# %% [markdown]
# **Relationship Extraction**

# %%
# Sample data: (sentence, relation)
data = [
    ("Dev Patel is late to college.", "is_late"),
    ("Bhadreshbhai had five apples.", "had_apples"),
]

# %%
# Separate sentences and labels
sentences = [sentence for sentence, _ in data]
labels = [label for _, label in data]

# %%
# Create a tokenizer and fit on sentences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

# %%
# Convert sentences to sequences of word indices
sequences = tokenizer.texts_to_sequences(sentences)

# %%
# Padding sequences for consistent input length
max_sequence_length = max([len(sequence) for sequence in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

# %%
# Create labels dictionary
label_indices = {"is_late": 0, "had_apples": 1}
labels_encoded = [label_indices[label] for label in labels]

# %%
# Convert labels to one-hot encoded vectors
labels_one_hot = tf.keras.utils.to_categorical(labels_encoded)

# %%
# Build RNN model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=128, input_length=max_sequence_length))
model.add(SimpleRNN(64, return_sequences=False))
model.add(Dense(len(label_indices), activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(padded_sequences, labels_one_hot, epochs=20, batch_size=31)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 0.7266 - accuracy: 0.0000e+00
# Epoch 2/20
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6154 - accuracy: 1.0000
# Epoch 3/20
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5172 - accuracy: 1.0000
# Epoch 4/20
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4294 - accuracy: 1.0000
# Epoch 5/20
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3506 - accuracy: 1.0000
# Epoch 6/20
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2806 - accuracy: 1.0000
# Epoch 7/20
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2197 - accuracy: 1.0000
# Epoch 8/20
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1680 - accuracy: 1.0000
# Epoch 9/20
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1255 - accuracy: 1.0000
# Epoch 10/20
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0918 - accuracy: 1.0000
# Epoch 11/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 12/20
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 13/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 14/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 15/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 16/20
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 17/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 18/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 19/20
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 20/20
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000

# %% [markdown]
# **Sample text for prediction**

# %%
# Sample sentence for prediction
sample_sentence = "Bhadressbhai was in possession of sixteen apples in Mehsana."

# %%
# Tokenize and pad the sample sentence
sample_sequence = tokenizer.texts_to_sequences([sample_sentence])
sample_padded_sequence = pad_sequences(sample_sequence, maxlen=max_sequence_length, padding='post')

# %%
# Predict the relation for the sample sentence
predicted_label_index = np.argmax(model.predict(sample_padded_sequence))
predicted_label = list(label_indices.keys())[predicted_label_index]

print(f"Predicted relation: {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 158ms/step
# Predicted relation: had_apples

# %% [markdown]
# **Template for NLTK using Information Extraction**

# %%
# Sample text
text = "Reliance Inc. was founded by Dhirubhai Ambani in Gujarat, in 1958."

# %%
# Tokenize the text into sentences and words
sentences = sent_tokenize(text)
words = [word_tokenize(sentence) for sentence in sentences]

# %%
# Part-of-speech tagging
pos_tags = [nltk.pos_tag(sentence) for sentence in words]

# %%
# Initialize variables to hold template placeholders
organization = ""
person = ""
location = ""
year = ""

# %%
# Iterate through the tagged words to extract information
for pos_tagged_sentence in pos_tags:
    for (word, pos) in pos_tagged_sentence:
        if pos == "NNP":  # Proper noun (likely an entity)
            if not organization:
                organization = word
            elif not person:
                person = word
            else:
                # Handle multiple proper nouns by assuming the last one is a person
                person = word
        elif pos == "IN" and not location:
            location = word
        elif pos == "CD" and not year:
            year = word

# %%
# Filter out stopwords
stop_words = set(stopwords.words("english"))
organization = organization.lower() if organization.lower() not in stop_words else ""
person = person.lower() if person.lower() not in stop_words else ""
location = location.lower() if location.lower() not in stop_words else ""

# %%
# Print the extracted information
print(f"Organization: {organization}")
print(f"Person: {person}")
print(f"Location: {location}")
print(f"Year: {year}")
# Out:
# Organization: reliance
# Person: gujarat
# Location:
# Year: 1958

# %%
# Define a template
template = "{organization} was founded by {person} in {location}, in {year}."
print(template)
# Fill the template
filled_template = template.format(
    organization=organization,
    person=person,
    location=location,
    year=year
)
# Out:
# {organization} was founded by {person} in {location}, in {year}.

# %%
# Print the filled template
print(filled_template)
# Out:
# reliance was founded by gujarat in , in 1958.

# %% [markdown]
# #**2. On Text Dataset**

# %% [markdown]
# **Using Spacy**

# %%
! pip install spacy
! python -m spacy download en_core_web_sm

# %%
import spacy

# %%
# Load the English language model
nlp = spacy.load("en_core_web_sm")

# %%
with open('/content/hlt-naacl08-data lab3 acl.txt', 'r') as file:
    text = file.read()

# %%
text
# Out:
# '<p1> Google </p1> assimilates <p2> YouTube </p2> !\nfinally <p1> google </p1> bought <p2> youtube </p2>\n<p1> Google </p1> actually bought <p2> YouTube </p2> .\n<p1> Google </p1> Closes <p2> YouTube </p2> Acquisition\nnever even saw this coming , but apparently <p1> Adobe </p1> www.msacromedia.com is about to buy <p2> Macromedia </p2> .\nThe story was first seen at Techcrunch , the picked up by the Wall Street Journal and has since been the subject of much talk , posts and thoughts over the past few days and finally it has been confirmed that <p1> Google </p1> have purchased <p2> Youtube </p2> for $ 1.65 billion in an official statement .\n<p1> Google </p1> confirms <p2> YouTube </p2> aquisition - BBC News\n<p1> Novartis </p1> acquired <p2> Eon Labs </p2> and Hexal to create the world s leading manufacturer of generic drugs .\n<p1> Novartis </p1> buys generic drugmakers <p2> Eon </p2> , Hexal\n<p1> Google </p1> announced Tuesday that it bought <p2> YouTube </p2> for $ 1.65 billion .\n<p1> Adobe </p1> has announced the acquisition of <p2> Macromedia </p2> .\nJuly 11 , 2005 __ __ __ ( Nasdaq : ADBE ) and __ __ __ ( Nasdaq : MACR ) today announced that they have received a Request for Additional Information and Documentary Materials ( a second request ) from the Department of Justice ( DOJ ) in connection with <p1> Adobe </p1> s pending acquisition of <p2> Macromedia </p2> .\nOfficial - <p1> Google </p1> Acquire <p2> YouTube </p2> For $ 1.65 Billion\nAnother example of a statutory merger is software maker <p1> Adobe Systems </p1> acquisition of <p2> Macromedia </p2> ( another software company ) .\nBASEL , Switzerland ( AP ) Swiss giant <p1> Novartis </p1> says it will buy generic drugmakers <p2> Eon Labs </p2> of the United States and Hexal of Germany for more than $ 8 billion in cash .\nThis week in the news we talk about <p1> Google </p1> actually does buy <p2> YouTube </p2> !\nThe __ founders talk about <p1> Google </p1> acquiring <p2> Youtube </p2>\nWhy did <p1> Google </p1> buy <p2> YouTube </p2> ?\nWhy Did <p1> Adobe </p1> Buy <p2> Macromedia </p2> ?\nAnd now that <p1> Google </p1> s got <p2> YouTube </p2> , they re gonna work that same magic on your independent short , hitting the guy in the head with a shovel [ plays video of just that ] .\n<p1> Novartis </p1> completes acquisition of 98 % of <p2> Eon Labs </p2> , substantially strengthening the leading position of its Sandoz generics unit ( Basel , July 21 , 2005 )\nBut who knows , with <p1> Google </p1> \' s " owning " of <p2> YouTube </p2> now...they are now in the " media " department with that deal...so who knows if they will move on to music stuff next : P\n<p1> Google </p1> snaps up <p2> YouTube </p2> for $ 1.65B\nIn October 2006 , <p1> Google </p1> buys <p2> Youtube </p2> for $ 1.65 billion .\n<p1> Google </p1> reportedly in talks to buy <p2> YouTube </p2> - Oct. 6 , 2006\nOn January 31 , 2006 , <p1> Viacom </p1> completed its acquisition of <p2> DreamWorks </p2> LLC ( __ ) , a producer of live - action motion pictures , television programming and home entertainment products .\nAnother <p1> Google </p1> Acquisition : <p2> YouTube </p2>\n__ - <p1> Adobe </p1> to acquire <p2> Macromedia </p2>\nOct. 10 : <p1> Google </p1> buys the online video sharing site <p2> YouTube </p2> for $ 1.65 billion in a deal expected to dramatically improve __ \' s video traffic .\n<p1> Google </p1> has acquired <p2> Youtube </p2> , an online video sharing service , for US $ 1.65B in __ stock .\n<p1> Adobe </p1> To Purchase <p2> Macromedia </p2>\nLast year Paramount , the <p1> Viacom </p1> - owned studio , bought <p2> Dreamworks </p2> , the studio behind Shrek , for $ 774m and $ 840m in debt .\nHmm , interesting question , what \' s in store for GMT now that <p1> Google </p1> announced buying <p2> YouTube </p2> .\nIn a $ 1.65 billion stock - for - stock transaction , search engine <p1> Google </p1> , will purchase <p2> YouTube </p2> , the consumer video media company .\n<p1> Novartis </p ...

# %%
doc = nlp(text)

# %%
doc

# %%
# Extract named entities
entities = [(entity.text, entity.label_) for entity in doc.ents]

# %%
# Print the named entities and their labels
for entity, label in entities:
    print(f"Entity: {entity}, Label: {label}")
# Out:
# Entity: Macromedia, Label: ORG
# Entity: Techcrunch, Label: ORG
# Entity: the Wall Street Journal, Label: ORG
# Entity: the past few days, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: BBC News, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: Hexal, Label: NORP
# Entity: Hexal
# <p1>, Label: PERSON
# Entity: Tuesday, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: July 11 , 2005, Label: DATE
# Entity: today, Label: DATE
# Entity: Request for Additional Information and Documentary Materials, Label: ORG
# Entity: second, Label: ORDINAL
# Entity: the Department of Justice, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: BASEL, Label: GPE
# Entity: Switzerland, Label: GPE
# Entity: AP, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: the United States, Label: GPE
# Entity: Hexal, Label: NORP
# Entity: Germany, Label: GPE
# Entity: more than $ 8 billion, Label: MONEY
# Entity: This week, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: 98 %, Label: PERCENT
# Entity: Eon Labs, Label: PERSON
# Entity: Sandoz, Label: ORG
# Entity: Basel, Label: GPE
# Entity: July 21 , 2005, Label: DATE
# Entity: 1.65B, Label: MONEY
# Entity: October 2006, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Oct. 6 , 2006, Label: DATE
# Entity: January 31 , 2006, Label: DATE
# Entity: Viacom, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: Oct. 10, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: US, Label: GPE
# Entity: 1.65B, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: Last year, Label: DATE
# Entity: Paramount, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Shrek, Label: PERSON
# Entity: 774, Label: MONEY
# Entity: 840, Label: MONEY
# Entity: Hmm, Label: GPE
# Entity: GMT, Label: ORG
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Hexal, Label: PERSON
# Entity: Eon Labs, Label: PERSON
# Entity: today, Label: DATE
# Entity: Chad Hurley, Label: PERSON
# Entity: Steve Chen, Label: PERSON
# Entity: Macromedia, Label: ORG
# Entity: April 18 , 2005, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: two, Label: CARDINAL
# Entity: August 24 , 2005, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: today, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: today, Label: DATE
# Entity: WSJ, Label: ORG
# Entity: today, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: US, Label: GPE
# Entity: Eon Labs, Label: PERSON
# Entity: one, Label: CARDINAL
# Entity: Streamingmedia.com, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: General News - www.pcauthority.com.au, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: Paul Daniels, Label: PERSON
# Entity: roughly twenty five, Label: CARDINAL
# Entity: Globe and Mail, Label: ORG
# Entity: Yahoo, Label: ORG
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: a year, Label: DATE
# Entity: Viacom, Label: ORG
# Entity: DreamWorks Pictures, Label: ORG
# Entity: ShoeMoney, Label: PRODUCT
# Entity: Friday , October 6th, Label: DATE
# Entity: Eon Labs, Label: PERSON
# Entity: Purchase, Label: PERSON
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 Billion, Label: MONEY
# Entity: 1.65Billion, Label: MONEY
# Entity: 1.65, Label: MONEY
# Entity: $ 1.65 million, Label: MONEY
# Entity: yesterday, Label: DATE
# Entity: Chad Hurley, Label: PERSON
# Entity: Steve Chen, Label: PERSON
# Entity: two, Label: CARDINAL
# Entity: 1.6B, Label: MONEY
# Entity: $ 1.65 billion, Label: MONEY
# Entity: October 9 , 2006, Label: DATE
# Entity: the days, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Yahoo, Label: ORG
# Entity: The War Is Over : <p1, Label: EVENT
# Entity: 883million, Label: CARDINAL
# Entity: Monday, Label: DATE
# Entity: US, Label: GPE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: December 3 , 2005, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Commission, Label: ORG
# Entity: ER, Label: WORK_OF_ART
# Entity: the United States, Label: GPE
# Entity: Amide, Label: GPE
# Entity: 10 days, Label: DATE
# Entity: Adobe Systems Inc., Label: ORG
# Entity: Macromedia Inc., Label: ORG
# Entity: Wednesday, Label: DATE
# Entity: later this year, Label: DATE
# Entity: Sumner Redstone, Label: PERSON
# Entity: Board, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Microsoft, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: San Jose, Label: GPE
# Entity: Calif., Label: GPE
# Entity: April, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Flash, Label: PERSON
# Entity: the Wall Street Journal, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Paramount Pictures, Label: ORG
# Entity: $ 1.6 billion, Label: MONEY
# Entity: NBC Universal, Label: ORG
# Entity: Steven Spielberg, Label: PERSON
# Entity: 1.65 Billion dollar, Label: MONEY
# Entity: 98, Label: CARDINAL
# Entity: Eon Labs, Label: PERSON
# Entity: 8217, Label: MONEY
# Entity: The Flash Player, Label: WORK_OF_ART
# Entity: Macromedia, Label: ORG
# Entity: Novartis AG, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: US, Label: GPE
# Entity: Hexal AG, Label: ORG
# Entity: German, Label: NORP
# Entity: $ 8.3 billion, Label: MONEY
# Entity: today, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: CNN, Label: ORG
# Entity: $ 1.65 billion, Label: MONEY
# Entity: February 2005, Label: DATE
# Entity: October, Label: DATE
# Entity: $ US1.65 billion, Label: MONEY
# Entity: $ 2.21 billion, Label: MONEY
# Entity: 1.6 Billion dollars, Label: MONEY
# Entity: today, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: the weekend, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: 67, Label: CARDINAL
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: first, Label: ORDINAL
# Entity: Macromedia, Label: ORG
# Entity: December 14 , 2005, Label: DATE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: one, Label: CARDINAL
# Entity: German, Label: NORP
# Entity: Lutz Dammbeck, Label: PERSON
# Entity: 98 %, Label: PERCENT
# Entity: Eon Labs, Label: PERSON
# Entity: Hexal, Label: PERSON
# Entity: 5.6 billion, Label: CARDINAL
# Entity: Techcrunch, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: 2005, Label: DATE
# Entity: Paramount, Label: ORG
# Entity: $ 1.6 billion, Label: MONEY
# Entity: 914 million, Label: CARDINAL
# Entity: M &, Label: ORG
# Entity: 4, Label: CARDINAL
# Entity: Verizon Communications, Label: ORG
# Entity: MCI, Label: ORG
# Entity: SBC Communications Corp., Label: ORG
# Entity: AT &amp;amp, Label: ORG
# Entity: T Corp., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: T Sprint Corp., Label: ORG
# Entity: Nextel Communications, Label: ORG
# Entity: 16, Label: CARDINAL
# Entity: Sprint Nextel Corp., Label: ORG
# Entity: 19, Label: CARDINAL
# Entity: Viacom, Label: ORG
# Entity: 23, Label: CARDINAL
# Entity: Federated Department Stores, Label: ORG
# Entity: May Department Stores, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: $ 1.6 billion, Label: MONEY
# Entity: yesterday, Label: DATE
# Entity: late Thursday, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 billion, Label: MONEY
# Entity: Adobe Systems Inc., Label: ORG
# Entity: Macromedia Inc., Label: ORG
# Entity: $ 3.4 billion, Label: MONEY
# Entity: two, Label: CARDINAL
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 Billion, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: NBC Universal, Label: ORG
# Entity: Adotas, Label: ORG
# Entity: Shackles, Label: GPE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: Time Warner, Label: ORG
# Entity: Reuters, Label: ORG
# Entity: 18, Label: CARDINAL
# Entity: Monday , February 21 , 2005, Label: DATE
# Entity: Novartis AG, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: TMO Reports - <p1>, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 Billion, Label: MONEY
# Entity: 0.69, Label: CARDINAL
# Entity: Macromedia, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: approximately $ 3.4 billion, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: this morning, Label: TIME
# Entity: $ 1.6 Billion, Label: MONEY
# Entity: approximately 98 %, Label: PERCENT
# Entity: Eon Labs, Label: PERSON
# Entity: Sandoz, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: Eon Labs, Label: PERSON
# Entity: 1.65billion, Label: MONEY
# Entity: 883million, Label: CARDINAL
# Entity: Chizen, Label: ORG
# Entity: U.S., Label: GPE
# Entity: Macromedia, Label: ORG
# Entity: U.S., Label: GPE
# Entity: Today, Label: DATE
# Entity: $ 3.4 billion, Label: MONEY
# Entity: 0.69 <p1, Label: CARDINAL
# Entity: Macromedia, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: Said, Label: PERSON
# Entity: New York Times, Label: ORG
# Entity: Novartis AG, Label: ORG
# Entity: Hexal, Label: PERSON
# Entity: Sandoz, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 billion, Label: MONEY
# Entity: $ 1.65 billion, Label: MONEY
# Entity: 1.65bn, Label: MONEY
# Entity: a year from now, Label: DATE
# Entity: the Paramount Agreements and <p1, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Studios, Label: PERSON
# Entity: Studios, Label: PERSON
# Entity: $ 75 million, Label: MONEY
# Entity: Paramount, Label: ORG
# Entity: approximately $ 49 million, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: 11 years ago, Label: DATE
# Entity: Jeffrey Katzenberg, Label: PERSON
# Entity: Spielberg, Label: PERSON
# Entity: Geffen, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: one day, Label: DATE
# Entity: Google Inc., Label: ORG
# Entity: YouTube Inc., Label: ORG
# Entity: $ 1.65 billion, Label: MONEY
# Entity: $ 1.65 - billion, Label: MONEY
# Entity: The Federal Trade Commission, Label: ORG
# Entity: Staunton News, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Paramount, Label: ORG
# Entity: $ 1.6 Billion, Label: MONEY
# Entity: Chad, Label: GPE
# Entity: Steve, Label: PERSON
# Entity: Buy Hexal, Label: PERSON
# Entity: Eon Labs, Label: PERSON
# Entity: $ 8.3 Billion, Label: MONEY
# Entity: 39, Label: CARDINAL
# Entity: The New York Times, Label: ORG
# Entity: december 12, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Levine Breaking News, Label: ORG
# Entity: Newsweek, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: one third, Label: CARDINAL
# Entity: the New York Stock Exchange, Label: ORG
# Entity: NYSE, Label: ORG
# Entity: around $ 1 billion, Label: MONEY
# Entity: Blog Archive &, Label: ORG
# Entity: 1.6 billion, Label: CARDINAL
# Entity: 67.7 percent, Label: PERCENT
# Entity: Eon Labs, Label: PERSON
# Entity: Santo Holding ( Deutschland ) GmbH, Label: ORG
# Entity: August 2005, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: yesterday, Label: DATE
# Entity: $ 165 billion dollars, Label: MONEY
# Entity: ABC News, Label: ORG
# Entity: 3.4, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: Macromedia Inc., Label: ORG
# Entity: this year, Label: DATE
# Entity: 14 December, Label: DATE
# Entity: Sterling, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Paramount Pictures, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: $ 1.65 BILLION, Label: MONEY
# Entity: FTC, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: 1.65bn, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 billion, Label: MONEY
# Entity: Hexal AG, Label: ORG
# Entity: Eon Labs, Label: PERSON
# Entity: Viacom, Label: ORG
# Entity: about $ 600 million, Label: MONEY
# Entity: YouTube Inc., Label: ORG
# Entity: $ 1.6 billion, Label: MONEY
# Entity: The Wall Street Journal, Label: ORG
# Entity: this afternoon, Label: TIME
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: Eon Labs, Label: PERSON
# Entity: Sandoz, Label: ORG
# Entity: 67.5 %, Label: PERCENT
# Entity: Eon Labs, Label: PERSON
# Entity: Users for 1.65 Billion, Label: ORG
# Entity: Ms Reider, Label: PERSON
# Entity: September, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: 1.65 billions, Label: MONEY
# Entity: Viacom, Label: ORG
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: Viacom, Label: ORG
# Entity: Studio, Label: PERSON
# Entity: Viacom, Label: ORG
# Entity: CBS Paramount Television, Label: ORG
# Entity: Shrek and Gladiator, Label: WORK_OF_ART
# Entity: Spin City, Label: GPE
# Entity: Paramount, Label: ORG
# Entity: 2000, Label: DATE
# Entity: Sumner Redstone, Label: PERSON
# Entity: Board, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: Paramount Pictures, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: $ 1.6 billion, Label: MONEY
# Entity: $ 774 million, Label: MONEY
# Entity: Eon Labs, Label: PERSON
# Entity: Hexal
# Will the <p1>, Label: PERSON
# Entity: MySpace, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 billion, Label: MONEY
# Entity: Viacom, Label: ORG
# Entity: Corel, Label: GPE
# Entity: Macromedia, Label: ORG
# Entity: KYW, Label: ORG
# Entity: Ian Bush, Label: PERSON
# Entity: KYW Tech, Label: ORG
# Entity: Bob Bicknell, Label: PERSON
# Entity: $ 1.65 billion, Label: MONEY
# Entity: Shearman &amp;amp, Label: ORG
# Entity: Sterling Advises <p1, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: $ 1.7 billion, Label: MONEY
# Entity: Viacom, Label: ORG
# Entity: Google Inc., Label: ORG
# Entity: YouTube Inc., Label: ORG
# Entity: US, Label: GPE
# Entity: $ 1.65 billion, Label: MONEY
# Entity: yesterday, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Last week, Label: DATE
# Entity: 1.65 billion Dollars, Label: MONEY
# Entity: 1.65bn, Label: MONEY
# Entity: 883, Label: CARDINAL
# Entity: a weekend, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: $ 3.4 Billion, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: BusinessWeek, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: Steve Ballmer, Label: PERSON
# Entity: Earlier this month, Label: DATE
# Entity: Viacom, Label: ORG
# Entity: $ 75 million, Label: MONEY
# Entity: Macromedia, Label: ORG
# Entity: Clears U.S. Department of Justice Review, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: Dreamweaver, Label: ORG
# Entity: Flash, Label: PERSON
# Entity: Studio, Label: PERSON
# Entity: University, Label: ORG
# Entity: AJCU, Label: ORG
# Entity: this afternoon, Label: TIME
# Entity: evening, Label: TIME
# Entity: 1.6 billion, Label: CARDINAL
# Entity: Yesterday, Label: DATE
# Entity: Macromedia Inc., Label: ORG
# Entity: $ 3.4 billion, Label: MONEY
# Entity: Commission, Label: ORG
# Entity: Flash, Label: PERSON
# Entity: Macromedia, Label: ORG
# Entity: October 9 , 2006, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Saturday , December 3, Label: DATE
# Entity: Thursday, Label: DATE
# Entity: night, Label: TIME
# Entity: Macromedia, Label: ORG
# Entity: Clears U.S. Department of Justice, Label: ORG
# Entity: last week, Label: DATE
# Entity: $ 1.65 Billion, Label: MONEY
# Entity: 98 %, Label: PERCENT
# Entity: Eon Labs, Label: PERSON
# Entity: December, Label: DATE
# Entity: Viacom Inc <, Label: ORG
# Entity: Paramount, Label: ORG
# Entity: Viacom, Label: ORG
# Entity: early 2006, Label: DATE
# Entity: Buy Hexal, Label: PERSON
# Entity: Eon Labs, Label: PERSON
# Entity: Wednesday, Label: DATE
# Entity: Macromedia, Label: ORG
# Entity: Macromedia, Label: ORG
# Entity: 1.38, Label: CARDINAL
# Entity: Macromedia, Label: ORG
# Entity: Google , Inc. <, Label: ORG
# Entity: December, Label: DATE
# Entity: Viacom, Label: ORG
# Entity: Paramount, Label: ORG
# Entity: 1994, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: George Gershwin, Label: PERSON
# Entity: 1898 - 1937, Label: DATE
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: Las Vegas, Label: GPE
# Entity: Nev, Label: PERSON
# Entity: Franz Kafka, Label: PERSON
# Entity: Bohemia, Label: PERSON
# Entity: this day, Label: DATE
# Entity: 1883, Label: DATE
# Entity: College Preparatory Academy, Label: ORG
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: 1883, Label: DATE
# Entity: Franz Kafka, Label: PERSON
# Entity: German, Label: NORP
# Entity: Jewish, Label: NORP
# Entity: Czechoslovakia, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: April 29 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: 1986, Label: DATE
# Entity: 24 Hour, Label: TIME
# Entity: Super - Sport Clubs, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 1883, Label: DATE
# Entity: the Czech Republic, Label: GPE
# Entity: Austria, Label: GPE
# Entity: Charles Spencer <p1, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: 16 April 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: 25 December 1977, Label: DATE
# Entity: Corsier sur Vevey, Label: ORG
# Entity: Switzerland, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: April 29th 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 1883 - 1924, Label: DATE
# Entity: Czechoslovakia, Label: GPE
# Entity: Jewish, Label: NORP
# Entity: Franz Kafka, Label: PERSON
# Entity: German, Label: NORP
# Entity: Jewish, Label: NORP
# Entity: 1883, Label: DATE
# Entity: the Austrian Empire, Label: GPE
# Entity: 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: Armenian, Label: NORP
# Entity: Las Vegas, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 1883, Label: DATE
# Entity: the 29th of April 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Charles Spencer <p1, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: April 16th 1889, Label: DATE
# Entity: Charles Spencer, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: 1989, Label: DATE
# Entity: America, Label: GPE
# Entity: Charles Spencer, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: Jr, Label: PERSON
# Entity: April 16 , 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: Christmas Day, Label: DATE
# Entity: December 25 , 1977, Label: DATE
# Entity: Switzerland, Label: GPE
# Entity: age 88, Label: DATE
# Entity: Franz Kafka, Label: PERSON
# Entity: 1883 - 1924, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: a few years ago, Label: DATE
# Entity: opening night, Label: TIME
# Entity: the36 - year - old, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Andrei Pavel of Romania on Center Court, Label: ORG
# Entity: Charlie Chaplin, Label: PERSON
# Entity: April 15 , 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: Charles, Label: PERSON
# Entity: Sr., Label: GPE
# Entity: Hannah Hill, Label: PERSON
# Entity: Lynn, Label: PERSON
# Entity: Kenneth, Label: PERSON
# Entity: pg.376, Label: GPE
# Entity: years, Label: DATE
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: April 29 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: World No, Label: EVENT
# Entity: 1, Label: CARDINAL
# Entity: the United States, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3 , 1883, Label: DATE
# Entity: George Gershwin, Label: PERSON
# Entity: Jacob Gershowitz, Label: PERSON
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: 1898, Label: DATE
# Entity: Agassi, Label: PERSON
# Entity: April 29 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: World No. 1, Label: ORG
# Entity: the United States, Label: GPE
# Entity: Charles Spencer <p1>, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: April 16 , 1889, Label: DATE
# Entity: Lambeth, Label: PERSON
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: UK, Label: GPE
# Entity: December 25 , 1977, Label: DATE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: 1889, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: millions of dollars, Label: MONEY
# Entity: Grand Slam for Children, Label: WORK_OF_ART
# Entity: Kafka, Label: PERSON
# Entity: Franz, Label: ORG
# Entity: Birthplace, Label: PERSON
# Entity: 1883, Label: DATE
# Entity: 1924, Label: DATE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: 1977, Label: DATE
# Entity: London, Label: GPE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Gullaume Guillaume Raoux, Label: PRODUCT
# Entity: France, Label: GPE
# Entity: the U.S. Open Tennis Tournament, Label: FAC
# Entity: New York, Label: GPE
# Entity: Thursday, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: 1970, Label: DATE
# Entity: Charles Spencer <p1, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: Walworth, Label: GPE
# Entity: London, Label: GPE
# Entity: April 16 , 1889, Label: DATE
# Entity: Andre Kirk <p1, Label: PERSON
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Kafka, Label: PERSON
# Entity: Jewish, Label: NORP
# Entity: Bohemia, Label: PERSON
# Entity: the Czech Republic, Label: GPE
# Entity: July 3 , 1883, Label: DATE
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Sciatica, Label: NORP
# Entity: two, Label: CARDINAL
# Entity: 1898 - 1937, Label: DATE
# Entity: George Gershwin, Label: PERSON
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: 26 September 1898, Label: DATE
# Entity: second, Label: ORDINAL
# Entity: four, Label: CARDINAL
# Entity: Morris, Label: PERSON
# Entity: Rose Gershovitz, Label: PERSON
# Entity: Russia, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3 , 1883, Label: DATE
# Entity: Bohemia, Label: PERSON
# Entity: Austria, Label: GPE
# Entity: Hungary, Label: GPE
# Entity: June 3 , 1924, Label: DATE
# Entity: Kierling, Label: GPE
# Entity: Vienna, Label: GPE
# Entity: Austria, Label: GPE
# Entity: Czech, Label: NORP
# Entity: German, Label: NORP
# Entity: Andre Kirk, Label: PERSON
# Entity: Emmanuel Mike <p1, Label: PERSON
# Entity: Agassi, Label: PERSON
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Mike, Label: PERSON
# Entity: Elizabeth, Label: PERSON
# Entity: 1898 - 1937, Label: DATE
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: Kafka, Label: PERSON
# Entity: Franz Kafka, Label: PERSON
# Entity: Jewish, Label: NORP
# Entity: 1883, Label: DATE
# Entity: Charles Spencer <p1, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: April 16 , 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: Charles, Label: PERSON
# Entity: Hannah, Label: PERSON
# Entity: Charlie Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: Las Vegas, Label: GPE
# Entity: 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: USA Trivia, Label: ORG
# Entity: a good week, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Jacob <p1>, Label: PERSON
# Entity: Sept. 26 , 1898, Label: DATE
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: the year 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3 , 1883, Label: DATE
# Entity: June 3 , 1924, Label: DATE
# Entity: Vienna, Label: GPE
# Entity: German, Label: NORP
# Entity: the 20th century, Label: DATE
# Entity: Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: George Gershwin, Label: PERSON
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: September 26 , 1898, Label: DATE
# Entity: Charles Spencer <p1, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: 16 April 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: UK, Label: GPE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: 1889 1977, Label: DATE
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 3 July 1883, Label: DATE
# Entity: George Gershwin, Label: PERSON
# Entity: Jacob Gershowitz, Label: PERSON
# Entity: 1898, Label: DATE
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 1883 - 1924, Label: DATE
# Entity: Jewish, Label: NORP
# Entity: George Gershwin, Label: PERSON
# Entity: September 26 , 1898, Label: DATE
# Entity: New York, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: the 29th of April , 1970, Label: DATE
# Entity: Charles Spencer <p1, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: 16 April 1889, Label: DATE
# Entity: George Gershwin, Label: PERSON
# Entity: American, Label: NORP
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: September 26 , 1898, Label: DATE
# Entity: Franz Kafka, Label: PERSON
# Entity: George Gershwin, Label: PERSON
# Entity: September 26 , 1898, Label: DATE
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: July 11 , 1937, Label: DATE
# Entity: Hollywood, Label: GPE
# Entity: California, Label: GPE
# Entity: Agassi, Label: PERSON
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Charles Spencer, Label: PERSON
# Entity: Chaplin, Label: PERSON
# Entity: Walworth, Label: GPE
# Entity: London, Label: GPE
# Entity: April 16 , 1889, Label: DATE
# Entity: 1970, Label: DATE
# Entity: Born Andre Kirk <p1, Label: PERSON
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3, Label: DATE
# Entity: Alstandt, Label: PERSON
# Entity: first, Label: ORDINAL
# Entity: Hermann, Label: PERSON
# Entity: 1852 - 1931, Label: DATE
# Entity: Julie, Label: PERSON
# Entity: 1856 - 1934, Label: DATE
# Entity: eight, Label: CARDINAL
# Entity: Grand Slam, Label: GPE
# Entity: Andre Kirk <p1, Label: PERSON
# Entity: Agassi, Label: PERSON
# Entity: 1970, Label: DATE
# Entity: this day, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: April 16 , 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: Eng, Label: PERSON
# Entity: Charlie Chaplin, Label: PERSON
# Entity: April 16 , 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: George Gershwin, Label: PERSON
# Entity: 1898 - 1937, Label: DATE
# Entity: New York, Label: GPE
# Entity: Russian - Jewish, Label: NORP
# Entity: Charlie Chaplin, Label: PERSON
# Entity: 1889 - 1977, Label: DATE
# Entity: London, Label: GPE
# Entity: Las Vegas, Label: GPE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: this day, Label: DATE
# Entity: 1889, Label: DATE
# Entity: London, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: Franz Kafka, Label: PERSON
# Entity: Hapsburg, Label: GPE
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: George Gershwin, Label: PERSON
# Entity: Jacob Gershovitz, Label: PERSON
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: September 26 , 1898, Label: DATE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: the United States, Label: GPE
# Entity: College Preparatory Academy, Label: ORG
# Entity: Las Vegas, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3 rd 1883, Label: DATE
# Entity: Austria - Hungary, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3 , 1883, Label: DATE
# Entity: Vienna, Label: GPE
# Entity: June 3 , 1924, Label: DATE
# Entity: Czech, Label: NORP
# Entity: German, Label: NORP
# Entity: George Gershwin, Label: PERSON
# Entity: September 26 , 1898, Label: DATE
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: 12, Label: CARDINAL
# Entity: George Gershwin, Label: PERSON
# Entity: Russian, Label: NORP
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: 1898, Label: DATE
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: 5, Label: CARDINAL
# Entity: Roddick, Label: PERSON
# Entity: Franz Kafka, Label: PERSON
# Entity: George Gershwin, Label: PERSON
# Entity: Jacob Gershvin, Label: PERSON
# Entity: Brooklyn, Label: GPE
# Entity: New York, Label: GPE
# Entity: 1898, Label: DATE
# Entity: Franz Kafka, Label: PERSON
# Entity: Metamorphosis, Label: PERSON
# Entity: Mission Impossible, Label: PERSON
# Entity: Tom Cruise, Label: PERSON
# Entity: David Robinson, Label: PERSON
# Entity: the San Antonio Spurs, Label: FAC
# Entity: San Antonio, Label: GPE
# Entity: Las Vegas, Label: GPE
# Entity: the United States, Label: GPE
# Entity: U.S., Label: GPE
# Entity: Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: England, Label: GPE
# Entity: U.S., Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 1883 - 1924, Label: DATE
# Entity: Austrian, Label: NORP
# Entity: Czech, Label: NORP
# Entity: The Trial, Label: ORG
# Entity: The Castle, Label: ORG
# Entity: America, Label: GPE
# Entity: 1927, Label: DATE
# Entity: Excerpt, Label: NORP
# Entity: Charlie Chaplin, Label: PERSON
# Entity: London, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: Bohemia, Label: PERSON
# Entity: Austria, Label: GPE
# Entity: July 3 , 1883, Label: DATE
# Entity: June 3 , 1924, Label: DATE
# Entity: this century, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: - Andre Kirk <p1, Label: PERSON
# Entity: Agassi, Label: PERSON
# Entity: 29 April 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Franz Kafka, Label: PERSON
# Entity: 3 juillet 1883, Label: DATE
# Entity: 1924, Label: DATE
# Entity: Kierling, Label: GPE
# Entity: un, Label: ORG
# Entity: Andre Kirk <p1, Label: PERSON
# Entity: Agassi, Label: PERSON
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: 60, Label: CARDINAL
# Entity: Franz Kafka, Label: PERSON
# Entity: July 3, Label: DATE
# Entity: Hermann, Label: PERSON
# Entity: Julie, Label: PERSON
# Entity: April 29 , 1970, Label: DATE
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: 1889, Label: DATE
# Entity: Charlie Chaplin, Label: PERSON
# Entity: English, Label: LANGUAGE
# Entity: London, Label: GPE
# Entity: College Preparatory Academy, Label: ORG
# Entity: Agassi, Label: PERSON
# Entity: Las Vegas, Label: GPE
# Entity: Nevada, Label: GPE
# Entity: Las Vegas, Label: GPE
# Entity: America Online, Label: PERSON
# Entity: Steve Case, Label: PERSON
# Entity: Exclusive Resorts, Label: WORK_OF_ART
# Entity: multi - million dollar, Label: MONEY
# Entity: Mattel, Label: ORG
# Entity: Ruth Handler, Label: PERSON
# Entity: 1959, Label: DATE
# Entity: Barbie, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: CSAIL, Label: PRODUCT
# Entity: Professor of Computer Science, Label: ORG
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: OBE FRS, Label: ORG
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: OBE, Label: ORG
# Entity: Alexander Lebed - Russian, Label: PERSON
# Entity: Boris Yeltsin, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: April 2002 - April 26 2002, Label: DATE
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: three, Label: CARDINAL
# Entity: the late fifties, Label: DATE
# Entity: Ruth Handler, Label: PERSON
# Entity: 10, Label: CARDINAL
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim, Label: PERSON
# Entity: 4 ., Label: CARDINAL
# Entity: Laws When <p1>, Label: WORK_OF_ART
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: 2, Label: CARDINAL
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: the Development of <, Label: ORG
# Entity: Mitchell Lane Publishers, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: 1959, Label: DATE
# Entity: Timothy <p1, Label: PERSON
# Entity: one, Label: CARDINAL
# Entity: 1989 - 91, Label: DATE
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: WWW, Label: ORG
# Entity: 1994, Label: DATE
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: 1959, Label: DATE
# Entity: The Great Idea Finder : <p1>, Label: WORK_OF_ART
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: 2001, Label: DATE
# Entity: The Creator of <, Label: WORK_OF_ART
# Entity: Lilli, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: Barbie Doll Creator Ruth Handler, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: next week, Label: DATE
# Entity: 1994, Label: DATE
# Entity: the Massachusetts Institute of Technology, Label: ORG
# Entity: Ruth Handler, Label: PERSON
# Entity: 1970, Label: DATE
# Entity: Ruth Handler, Label: PERSON
# Entity: one, Label: CARDINAL
# Entity: the Massachusetts Institute of Technology, Label: ORG
# Entity: Boston, Label: GPE
# Entity: The Great Idea Finder : <p1>, Label: WORK_OF_ART
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: June 8 , 1955, Label: DATE
# Entity: developerWorks, Label: ORG
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: 1996, Label: DATE
# Entity: the University of Southampton, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: TIM BERNERS - LEE STARTED, Label: ORG
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: 41, Label: CARDINAL
# Entity: British, Label: NORP
# Entity: TIM BERNERS - LEE, Label: PERSON
# Entity: 1955, Label: DATE
# Entity: the end of 1990, Label: DATE
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: 1959, Label: DATE
# Entity: National and International, Label: ORG
# Entity: 2002, Label: DATE
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Barbie, Label: PERSON
# Entity: Ruth Handler, Label: PERSON
# Entity: Mattel Toys, Label: ORG
# Entity: 1959, Label: DATE
# Entity: Queen Elizabeth, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: Tim Berners - Lee, Label: PERSON
# Entity: 1990 - 1991, Label: DATE
# Entity: CERN, Label: GPE
# Entity: the European Particle Physics Laboratory, Label: ORG
# Entity: Geneva, Label: GPE
# Entity: Wolfgang Amadeus, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: the early 1780 ' s, Label: DATE
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Truman, Label: PERSON
# Entity: 1945, Label: DATE
# Entity: Xanadu, Label: ORG
# Entity: Nelson, Label: PERSON
# Entity: XML, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: IE, Label: ORG
# Entity: John McCain, Label: PERSON
# Entity: Iraq, Label: GPE
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Quantum, Label: ORG
# Entity: Washington, Label: GPE
# Entity: Rose Garden, Label: FAC
# Entity: George W, Label: PERSON
# Entity: Bush, Label: PERSON
# Entity: Arizona, Label: GPE
# Entity: John McCain, Label: PERSON
# Entity: Wolfgang Amadeus, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: March 16 , 1781, Label: DATE
# Entity: Raymond V, Label: PERSON
# Entity: Damadian, Label: NORP
# Entity: 2003, Label: DATE
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Medicine, Label: ORG
# Entity: Paul Lauterbur, Label: PERSON
# Entity: Peter Mansfield, Label: PERSON
# Entity: Pemberton, Label: ORG
# Entity: Segway, Label: ORG
# Entity: ABC, Label: ORG
# Entity: Good Morning America, Label: FAC
# Entity: Monday morning, Label: TIME
# Entity: last week, Label: DATE
# Entity: first, Label: ORDINAL
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Physics, Label: ORG
# Entity: 1921, Label: DATE
# Entity: Ted Nelson, Label: PERSON
# Entity: Xanadu, Label: ORG
# Entity: Computer Lib, Label: PERSON
# Entity: December 2003, Label: DATE
# Entity: Richard G. Stearns, Label: PERSON
# Entity: Zoloft, Label: ORG
# Entity: Pharma, Label: PERSON
# Entity: Accupril, Label: PERSON
# Entity: America, Label: GPE
# Entity: Joseph Pulitzer, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: 2, Label: CARDINAL
# Entity: Microsoft, Label: ORG
# Entity: IM, Label: ORG
# Entity: the coming months, Label: DATE
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Google, Label: ORG
# Entity: Microsoft, Label: ORG
# Entity: AOL, Label: ORG
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: ten years, Label: DATE
# Entity: Gluck, Label: PERSON
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: John Pemberton, Label: PERSON
# Entity: 1921, Label: DATE
# Entity: Albert Einstein, Label: PERSON
# Entity: Microsoft, Label: ORG
# Entity: FT.com, Label: ORG
# Entity: 2, Label: CARDINAL
# Entity: 01 PM, Label: TIME
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: Microsoft, Label: ORG
# Entity: 4, Label: CARDINAL
# Entity: 06 PM, Label: TIME
# Entity: John Steinbeck, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: 1940, Label: DATE
# Entity: Mozart, Label: PERSON
# Entity: two months, Label: DATE
# Entity: Vienna, Label: PERSON
# Entity: June 4, Label: DATE
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: Colloredo, Label: PERSON
# Entity: Damadian, Label: NORP
# Entity: 2003, Label: DATE
# Entity: John Steinbeck, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: Sandoz, Label: ORG
# Entity: 1886, Label: DATE
# Entity: first, Label: ORDINAL
# Entity: 1781, Label: DATE
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: Pemberton, Label: ORG
# Entity: Spencerian, Label: NORP
# Entity: the Segway Human Transporter, Label: ORG
# Entity: Patents Covering Cancer Medicine and Antibiotic, Label: ORG
# Entity: Mozart, Label: PERSON
# Entity: December 5 , 1791, Label: DATE
# Entity: Vienna, Label: PERSON
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: Pemberton, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: Segway, Label: ORG
# Entity: Michelin, Label: PERSON
# Entity: Segway, Label: ORG
# Entity: Segway, Label: ORG
# Entity: the Segway Human Transporter, Label: ORG
# Entity: iBot, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: John Steinbeck, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: The Grapes of Wrath, Label: WORK_OF_ART
# Entity: The Red Pony, Label: LOC
# Entity: Atlanta, Label: GPE
# Entity: John Pemberton, Label: PERSON
# Entity: 1886, Label: DATE
# Entity: John Pemberton, Label: PERSON
# Entity: three, Label: CARDINAL
# Entity: Nelson, Label: PERSON
# Entity: Albert Einstein, Label: PERSON
# Entity: 1879 - 1955, Label: DATE
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: 1921, Label: DATE
# Entity: John Pemberton, Label: PERSON
# Entity: Harry Truman, Label: PERSON
# Entity: 58011, Label: DATE
# Entity: Teva Pharmaceutical Industries, Label: ORG
# Entity: Celebrex, Label: ORG
# Entity: 1886, Label: DATE
# Entity: John Pemberton, Label: PERSON
# Entity: Last fall, Label: DATE
# Entity: Dr, Label: GPE
# Entity: Raymond V, Label: PERSON
# Entity: Damadian, Label: NORP
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Raymond Damadian <, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Segway, Label: ORG
# Entity: Scooter, Label: PERSON
# Entity: Nelson, Label: PERSON
# Entity: XML, Label: ORG
# Entity: Berners - Lee 's, Label: PERSON
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: age 35, Label: DATE
# Entity: Truman, Label: PERSON
# Entity: Kennedy, Label: PERSON
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: Albert Einstein, Label: PERSON
# Entity: one, Label: CARDINAL
# Entity: Ulm, Label: GPE
# Entity: Germany, Label: GPE
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: 1921, Label: DATE
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Segway, Label: ORG
# Entity: Steinbeck, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: 1940, Label: DATE
# Entity: the Nobel Prize for Literature, Label: WORK_OF_ART
# Entity: 1962, Label: DATE
# Entity: Microsoft, Label: ORG
# Entity: Just a year later, Label: DATE
# Entity: 1762, Label: DATE
# Entity: Mozart, Label: PERSON
# Entity: Vienna, Label: PERSON
# Entity: 1921, Label: DATE
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Israel, Label: GPE
# Entity: Chaim Weizmanns, Label: ORG
# Entity: 1952, Label: DATE
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Quantum, Label: ORG
# Entity: Washington, Label: GPE
# Entity: Rose Garden, Label: FAC
# Entity: George W, Label: PERSON
# Entity: Bush, Label: PERSON
# Entity: Arizona, Label: GPE
# Entity: john McCain, Label: PERSON
# Entity: Watson, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: 1962, Label: DATE
# Entity: Maurice Wilkins, Label: PERSON
# Entity: James Watson, Label: PERSON
# Entity: Francis Crick, Label: PERSON
# Entity: two, Label: CARDINAL
# Entity: two, Label: CARDINAL
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Physics, Label: ORG
# Entity: 1921, Label: DATE
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Physics, Label: ORG
# Entity: 1921, Label: DATE
# Entity: Joseph Pulitzer, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: First, Label: ORDINAL
# Entity: Albert Einstein, Label: PERSON
# Entity: 1879 - 1955, Label: DATE
# Entity: German, Label: NORP
# Entity: American Physicist &amp;amp, Label: ORG
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Winner, Label: PERSON
# Entity: America, Label: GPE
# Entity: Joseph Pulitzer, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Albert Einstein, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Watson, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Watson, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Francis Crick, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Medicine, Label: GPE
# Entity: 1962, Label: DATE
# Entity: Watson, Label: PERSON
# Entity: Dr, Label: GPE
# Entity: Francis Crick, Label: PERSON
# Entity: Dr, Label: GPE
# Entity: Maurice Wilkins, Label: PERSON
# Entity: 1962, Label: DATE
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Nature, Label: WORK_OF_ART
# Entity: April of 1953, Label: DATE
# Entity: 1962, Label: DATE
# Entity: Maurice Wilkins, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Medicine, Label: GPE
# Entity: Steinbeck, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: Ford, Label: ORG
# Entity: Oscar, Label: WORK_OF_ART
# Entity: UC, Label: GPE
# Entity: San Diego, Label: GPE
# Entity: Francis Crick, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Medicine, Label: GPE
# Entity: John Steinbeck, Label: PERSON
# Entity: Pulitzer Prize, Label: WORK_OF_ART
# Entity: 1940, Label: DATE
# Entity: James Watson, Label: PERSON
# Entity: Francis Crick, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: 1962, Label: DATE
# Entity: More than Fifty years ago, Label: DATE
# Entity: James Watson, Label: PERSON
# Entity: Francis Crick, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Francis Crick, Label: PERSON
# Entity: James Watson, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART
# Entity: Watson, Label: PERSON
# Entity: Nobel Prize, Label: WORK_OF_ART

# %%
nlp = spacy.load("en_core_web_sm")
def info_retrieval(document):
  doc = nlp(document)
  organizations = []
  persons = []
  locations = []
  years = []
  for ent in doc.ents:
    if ent.label_ == "ORG":
        organizations.append(ent.text)
    elif ent.label_ == "PERSON":
        persons.append(ent.text)
    elif ent.label_ == "GPE":
        locations.append(ent.text)
    elif ent.label_ == "DATE":
        years.append(ent.text)
  return [("Organizations:", organizations), ("Persons:", persons), ("Locations:", locations), ("Years:", years)]

# %%
info_retrieval("Reliance Inc. was founded by Dhirubhai Ambani in Gujarat, in 1958.")
# Out:
# [('Organizations:', ['Reliance Inc.']),
#  ('Persons:', ['Dhirubhai Ambani']),
#  ('Locations:', ['Gujarat']),
#  ('Years:', ['1958'])]

# %%
model = opennre.get_model('wiki80_cnn_softmax')

def relation_extraction_opennre_from_xml(document):

    p1_text = re.findall(r'<p1>(.*?)</p1>', document)
    p2_text = re.findall(r'<p2>(.*?)</p2>', document)
    relationships = []
    for p1, p2 in zip(p1_text, p2_text):
        relation_info = model.infer({'text': f"{p1} {p2}", 'h': {'pos': (0, len(p1))}, 't': {'pos': (len(p1) + 1, len(p1) + len(p2) + 1)}})
        predicted_relation = relation_info[0]
        relationships.append((p1, predicted_relation, p2))

    return relationships

# %%
with open('/content/hlt-naacl08-data lab3 acl.txt', 'r', encoding='utf-8') as file:
    lines = file.readlines()

# %%
data = []
in_line =[]
p1_list = []
p2_list = []
ner_list = []
relationship_list = []

# %%
p1 = ""
p2 = ""

for line in lines:
    in_line.append(line)
    p1_match = re.search(r'<p1>(.*?)</p1>', line)

    if p1_match:
        p1 = p1_match.group(1)

    p2_match = re.search(r'<p2>(.*?)</p2>', line)
    if p2_match:
        p2 = p2_match.group(1)
    relationship_list.append(relation_extraction_opennre_from_xml(line))
    line = re.sub(r'<.*?>', '', line)

    ner_list.append(info_retrieval(line))
    in_line.append(line)
    p1_list.append(p1)
    p2_list.append(p2)

# %%
df = pd.DataFrame({'Input':lines, 'p1': p1_list, 'p2': p2_list, 'NER': ner_list,'Relationship Extraction': relationship_list})
df.head()
# Out:
#                                                Input        p1            p2  \
# 0  <p1> Google </p1> assimilates <p2> YouTube </p...   Google       YouTube
# 1  finally <p1> google </p1> bought <p2> youtube ...   google       youtube
# 2  <p1> Google </p1> actually bought <p2> YouTube...   Google       YouTube
# 3  <p1> Google </p1> Closes <p2> YouTube </p2> Ac...   Google       YouTube
# 4  never even saw this coming , but apparently <p...    Adobe    Macromedia
#
#                                                  NER  \
# 0  [(Organizations:, [Google, YouTube]), (Persons...
# 1  [(Organizations:, []), (Persons:, []), (Locati...
# 2  [(Organizations:, [Google, YouTube]), (Persons...
# 3  [(Organizations:, [Google  Closes  YouTube  Ac...
# 4  [(Organizations:, [Macromedia]), (Persons:, []...
#
#                           Relationship Extraction
# 0  [( Google , headquarters location,  YouTube )]
# 1  [( google , headquarters location,  youtube )]
# 2  [( Google , headquarters location,  YouTube )]
# 3  [( Google , headquarters location,  YouTube )]
# 4            [( Adobe , developer,  Macromedia )]

# %%
# !jupyter nbconvert --to html "/content/60009200040_ACL_D11_Lab4.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/60009200040_ACL_D11_Lab4.ipynb to html
# [NbConvertApp] Writing 775504 bytes to /content/60009200040_ACL_D11_Lab4.html
